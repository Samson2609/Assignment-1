# %% [markdown]
# <a href="https://colab.research.google.com/github/Samson2609/Assignment-1/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

# The paths below were causing a SyntaxError due to Windows-style backslashes
# and are also not valid in the Colab environment.
# Using the existing kernel variables 'zip_path' and 'extract_path' which are
# already set to the correct Colab-compatible paths.
# zip_path = "C:\Users\Admin\Downloads\pulse-master.zip\pulse-master\data"
# extract_path = "C:\Users\Admin\Downloads\pulse-master\pulse-master\data"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Unzipped Successfully!")
os.listdir(extract_path)
# Out:
# Unzipped Successfully!
# ['pulse-master']

# %%
import os

# The original path caused a SyntaxError due to Windows-style backslashes
# and is also not valid in the Colab environment.
# Using the existing kernel variable 'extract_path' which is
# already set to the correct Colab-compatible path.
base_path = extract_path
os.listdir(base_path)
# Out:
# ['pulse-master']

# %%
import os

# Recursively list the contents of the extract_path to understand the directory structure
for root, dirs, files in os.walk(extract_path):
    level = root.replace(extract_path, '').count(os.sep)
    indent = ' ' * 4 * (level)
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 4 * (level + 1)
    for f in files:
        print(f'{subindent}{f}')
# Out:
# pulse-master/
#     pulse-master/
#         README.md
#         LICENSE
#         .gitignore
#         data/
#             map/
#                 insurance/
#                     country/
#                         india/
#                             2021/
#                                 4.json
#                                 3.json
#                                 2.json
#                                 1.json
#                             2020/
#                                 4.json
#                                 3.json
#                                 2.json
#                             2024/
#                                 2.json
#                                 1.json
#                             2023/
#                                 4.json
#                                 3.json
#                                 2.json
#                                 1.json
#                             2022/
#                                 4.json
# ...

# %%
import sqlite3

conn = sqlite3.connect("phonepe.db")
cursor = conn.cursor()

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS aggregated_transaction (
    state TEXT,
    year INTEGER,
    quarter INTEGER,
    name TEXT,
    count INTEGER,
    amount REAL
)
""")
conn.commit()

# %%
df.to_sql("aggregated_transaction", conn, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2864735335.py in <cell line: 0>()
# ----> 1 df.to_sql("aggregated_transaction", conn, if_exists='append', index=False)
#
# NameError: name 'df' is not defined
